# %%
print('\U0001F910','\U0001F911','\U0001F912', '\U0001F913', '\U0001F914' , '\U0001F915', '\U0001F916' , '\U0001F917' )
print('\U0001F918','\U0001F919', '\U0001F920', '\U0001F921', '\U0001F922', '\U0001F923', '\U0001F924', '\U0001F924')
print('\U0001F925','\U0001F926', '\U0001F927', '\U0001F928', '\U0001F929', '\U0001F930', '\U0001F931', '\U0001F932')
print('\U0001F933','\U0001F934', '\U0001F935', '\U0001F936', '\U0001F937', '\U0001F938', '\U0001F939', '\U0001F940')
print('\U0001F941','\U0001F942', '\U0001F943', '\U0001F944', '\U0001F945', '\U0001F946', '\U0001F947', '\U0001F948')
print('\U0001F949','\U0001F950', '\U0001F951', '\U0001F952', '\U0001F953', '\U0001F954', '\U0001F955', '\U0001F956')
print('\U0001F957','\U0001F958', '\U0001F959', '\U0001F960', '\U0001F961', '\U0001F962', '\U0001F963', '\U0001F964')
print('\U0001F965','\U0001F966', '\U0001F967', '\U0001F968', '\U0001F969', '\U0001F970', '\U0001F971', '\U0001F972')
print('\U0001F973','\U0001F974', '\U0001F975', '\U0001F976', '\U0001F977', '\U0001F978', '\U0001F979', '\U0001F980')
print('\U0001F981','\U0001F982', '\U0001F983', '\U0001F984', '\U0001F985', '\U0001F986', '\U0001F987', '\U0001F988')
print('\U0001F989','\U0001F990', '\U0001F991', '\U0001F992', '\U0001F993', '\U0001F994', '\U0001F995', '\U0001F996')
print('\U0001F998','\U0001F999')
# Out:
# 🤐 🤑 🤒 🤓 🤔 🤕 🤖 🤗
# 🤘 🤙 🤠 🤡 🤢 🤣 🤤 🤤
# 🤥 🤦 🤧 🤨 🤩 🤰 🤱 🤲
# 🤳 🤴 🤵 🤶 🤷 🤸 🤹 🥀
# 🥁 🥂 🥃 🥄 🥅 🥆 🥇 🥈
# 🥉 🥐 🥑 🥒 🥓 🥔 🥕 🥖
# 🥗 🥘 🥙 🥠 🥡 🥢 🥣 🥤
# 🥥 🥦 🥧 🥨 🥩 🥰 🥱 🥲
# 🥳 🥴 🥵 🥶 🥷 🥸 🥹 🦀
# 🦁 🦂 🦃 🦄 🦅 🦆 🦇 🦈
# 🦉 🦐 🦑 🦒 🦓 🦔 🦕 🦖
# 🦘 🦙
